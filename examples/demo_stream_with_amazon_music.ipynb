# %% [markdown]
# # Demo of recnexteval Stream
#
# - Dataset: AmazonMusicDataset
# - Algorithm: ItemKNN Incremental

# %%
from recnexteval.datasets import AmazonMusicDataset
from recnexteval.settings import SlidingWindowSetting


k = 100
dataset = AmazonMusicDataset()
data = dataset.load()

setting_window = SlidingWindowSetting(
    background_t=1600052710,
    window_size=60 * 60 * 24 * 30,  # day times N
    top_K=k
)

setting_window.split(data)
# Out:
# INFO - recnexteval package loaded.
# DEBUG - AmazonMusicDataset being initialized with '/Users/ngtzekean/personal/RecNextEval/data/amazon' as the base path.
# DEBUG - AmazonMusicDataset is initialized.
# INFO - AmazonMusicDataset is loading dataset...
# INFO - Loading from cache: /Users/ngtzekean/personal/RecNextEval/data/amazon/Digital_Music.jsonl.gz.processed.parquet
# DEBUG - AmazonMusicDataset applying filters set.
# DEBUG - 	interactions before preprocess: 130434
# DEBUG - 	items before preprocess: 70511
# DEBUG - 	users before preprocess: 100952
# DEBUG - 	interactions after preprocess: 130434
# DEBUG - 	items after preprocess: 70511
# DEBUG - 	users after preprocess: 100952
# INFO - AmazonMusicDataset dataset loaded - Took 0.106s
# DEBUG - Splitting data...
# DEBUG - Performing lt(t, 2147483647)
# DEBUG - Performing lt(t, 1600052710)
# DEBUG - Performing ge(t, 1600052710)
# DEBUG - TimestampSplitter(t=1600052710,t_lower=None,t_upper=None) has complete split
#   0%|          | 0/36 [00:00<?, ?it/s]
# DEBUG - NLastInteractionTimestampSplitter(t=1600052710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1600052710
# DEBUG - Performing lt(t, 1602644710)
# DEBUG - Performing ge(t, 1600052710)
# DEBUG - NLastInteractionTimestampSplitter(t=1600052710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1600052710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1600052710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1602644710
# DEBUG - Performing lt(t, 1605236710)
# DEBUG - Performing ge(t, 1602644710)
# DEBUG - NLastInteractionTimestampSplitter(t=1602644710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1602644710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1602644710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1605236710
# DEBUG - Performing lt(t, 1607828710)
# DEBUG - Performing ge(t, 1605236710)
# DEBUG - NLastInteractionTimestampSplitter(t=1605236710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1605236710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1605236710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1607828710
# DEBUG - Performing lt(t, 1610420710)
# DEBUG - Performing ge(t, 1607828710)
# DEBUG - NLastInteractionTimestampSplitter(t=1607828710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1607828710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1607828710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1610420710
# DEBUG - Performing lt(t, 1613012710)
# DEBUG - Performing ge(t, 1610420710)
# DEBUG - NLastInteractionTimestampSplitter(t=1610420710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1610420710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1610420710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1613012710
# DEBUG - Performing lt(t, 1615604710)
# DEBUG - Performing ge(t, 1613012710)
# DEBUG - NLastInteractionTimestampSplitter(t=1613012710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1613012710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1613012710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1615604710
# DEBUG - Performing lt(t, 1618196710)
# DEBUG - Performing ge(t, 1615604710)
# DEBUG - NLastInteractionTimestampSplitter(t=1615604710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1615604710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1615604710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1618196710
# DEBUG - Performing lt(t, 1620788710)
# DEBUG - Performing ge(t, 1618196710)
# DEBUG - NLastInteractionTimestampSplitter(t=1618196710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1618196710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1618196710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1620788710
# DEBUG - Performing lt(t, 1623380710)
# DEBUG - Performing ge(t, 1620788710)
# DEBUG - NLastInteractionTimestampSplitter(t=1620788710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1620788710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1620788710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1623380710
# DEBUG - Performing lt(t, 1625972710)
# DEBUG - Performing ge(t, 1623380710)
# DEBUG - NLastInteractionTimestampSplitter(t=1623380710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1623380710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1623380710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1625972710
# DEBUG - Performing lt(t, 1628564710)
# DEBUG - Performing ge(t, 1625972710)
# DEBUG - NLastInteractionTimestampSplitter(t=1625972710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1625972710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1625972710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1628564710
# DEBUG - Performing lt(t, 1631156710)
# DEBUG - Performing ge(t, 1628564710)
# DEBUG - NLastInteractionTimestampSplitter(t=1628564710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1628564710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1628564710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1631156710
# DEBUG - Performing lt(t, 1633748710)
# DEBUG - Performing ge(t, 1631156710)
# DEBUG - NLastInteractionTimestampSplitter(t=1631156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1631156710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1631156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1633748710
# DEBUG - Performing lt(t, 1636340710)
# DEBUG - Performing ge(t, 1633748710)
# DEBUG - NLastInteractionTimestampSplitter(t=1633748710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1633748710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1633748710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1636340710
# DEBUG - Performing lt(t, 1638932710)
# DEBUG - Performing ge(t, 1636340710)
# DEBUG - NLastInteractionTimestampSplitter(t=1636340710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1636340710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1636340710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1638932710
# DEBUG - Performing lt(t, 1641524710)
# DEBUG - Performing ge(t, 1638932710)
# DEBUG - NLastInteractionTimestampSplitter(t=1638932710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1638932710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1638932710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1641524710
# DEBUG - Performing lt(t, 1644116710)
# DEBUG - Performing ge(t, 1641524710)
# DEBUG - NLastInteractionTimestampSplitter(t=1641524710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1641524710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1641524710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1644116710
# DEBUG - Performing lt(t, 1646708710)
# DEBUG - Performing ge(t, 1644116710)
# DEBUG - NLastInteractionTimestampSplitter(t=1644116710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1644116710 resulted in empty unlabelled testing samples.
#  50%|█████     | 18/36 [00:00<00:00, 176.72it/s]
# DEBUG - NLastInteractionTimestampSplitter(t=1644116710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1646708710
# DEBUG - Performing lt(t, 1649300710)
# DEBUG - Performing ge(t, 1646708710)
# DEBUG - NLastInteractionTimestampSplitter(t=1646708710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1646708710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1646708710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1649300710
# DEBUG - Performing lt(t, 1651892710)
# DEBUG - Performing ge(t, 1649300710)
# DEBUG - NLastInteractionTimestampSplitter(t=1649300710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1649300710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1649300710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1651892710
# DEBUG - Performing lt(t, 1654484710)
# DEBUG - Performing ge(t, 1651892710)
# DEBUG - NLastInteractionTimestampSplitter(t=1651892710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1651892710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1651892710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1654484710
# DEBUG - Performing lt(t, 1657076710)
# DEBUG - Performing ge(t, 1654484710)
# DEBUG - NLastInteractionTimestampSplitter(t=1654484710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1654484710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1654484710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1657076710
# DEBUG - Performing lt(t, 1659668710)
# DEBUG - Performing ge(t, 1657076710)
# DEBUG - NLastInteractionTimestampSplitter(t=1657076710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1657076710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1657076710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1659668710
# DEBUG - Performing lt(t, 1662260710)
# DEBUG - Performing ge(t, 1659668710)
# DEBUG - NLastInteractionTimestampSplitter(t=1659668710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1659668710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1659668710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1662260710
# DEBUG - Performing lt(t, 1664852710)
# DEBUG - Performing ge(t, 1662260710)
# DEBUG - NLastInteractionTimestampSplitter(t=1662260710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1662260710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1662260710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1664852710
# DEBUG - Performing lt(t, 1667444710)
# DEBUG - Performing ge(t, 1664852710)
# DEBUG - NLastInteractionTimestampSplitter(t=1664852710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1664852710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1664852710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1667444710
# DEBUG - Performing lt(t, 1670036710)
# DEBUG - Performing ge(t, 1667444710)
# DEBUG - NLastInteractionTimestampSplitter(t=1667444710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1667444710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1667444710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1670036710
# DEBUG - Performing lt(t, 1672628710)
# DEBUG - Performing ge(t, 1670036710)
# DEBUG - NLastInteractionTimestampSplitter(t=1670036710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1670036710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1670036710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1672628710
# DEBUG - Performing lt(t, 1675220710)
# DEBUG - Performing ge(t, 1672628710)
# DEBUG - NLastInteractionTimestampSplitter(t=1672628710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1672628710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1672628710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1675220710
# DEBUG - Performing lt(t, 1677812710)
# DEBUG - Performing ge(t, 1675220710)
# DEBUG - NLastInteractionTimestampSplitter(t=1675220710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1675220710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1675220710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1677812710
# DEBUG - Performing lt(t, 1680404710)
# DEBUG - Performing ge(t, 1677812710)
# DEBUG - NLastInteractionTimestampSplitter(t=1677812710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1677812710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1677812710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1680404710
# DEBUG - Performing lt(t, 1682996710)
# DEBUG - Performing ge(t, 1680404710)
# DEBUG - NLastInteractionTimestampSplitter(t=1680404710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1680404710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1680404710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1682996710
# DEBUG - Performing lt(t, 1685588710)
# DEBUG - Performing ge(t, 1682996710)
# DEBUG - NLastInteractionTimestampSplitter(t=1682996710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1682996710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1682996710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1685588710
# DEBUG - Performing lt(t, 1688180710)
# DEBUG - Performing ge(t, 1685588710)
# DEBUG - NLastInteractionTimestampSplitter(t=1685588710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1685588710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1685588710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1688180710
# DEBUG - Performing lt(t, 1690772710)
# DEBUG - Performing ge(t, 1688180710)
# DEBUG - NLastInteractionTimestampSplitter(t=1688180710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1688180710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1688180710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1690772710
# DEBUG - Performing lt(t, 1693364710)
# DEBUG - Performing ge(t, 1690772710)
# DEBUG - NLastInteractionTimestampSplitter(t=1690772710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1690772710 resulted in empty unlabelled testing samples.
# 100%|██████████| 36/36 [00:00<00:00, 178.57it/s]
# DEBUG - NLastInteractionTimestampSplitter(t=1690772710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1693364710
# DEBUG - Performing lt(t, 1695956710)
# DEBUG - Performing ge(t, 1693364710)
# DEBUG - NLastInteractionTimestampSplitter(t=1693364710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1693364710 resulted in empty unlabelled testing samples.
# 37it [00:00, 179.23it/s]
# INFO - Finished split with window size 2592000 seconds. Number of splits: 37 in total.
# INFO - SlidingWindowSetting data split - Took 0.223s
# DEBUG - Checking split attribute and sizes.
# DEBUG - Checking split attributes.
# DEBUG - Split attributes are set.
# DEBUG - Checking size of split sets.
# DEBUG - Size of split sets are checked.
# INFO - SlidingWindowSetting data split complete.

# %%
from recnexteval.evaluators import EvaluatorStreamerBuilder


builder = EvaluatorStreamerBuilder()
builder.add_setting(setting_window)
builder.set_metric_k(k)
builder.add_metric("PrecisionK")
builder.add_metric("RecallK")
evaluator = builder.build()

# %%
from recnexteval.algorithms import ItemKNNIncremental


external_model = ItemKNNIncremental(K=k)
external_model_id = evaluator.register_algorithm(algorithm_name="ItemKNNIncremental", algorithm=external_model)
print(external_model_id)
# Out:
# INFO - Registered algorithm 'ItemKNNIncremental' with ID cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c registered
# cb605b33-7733-5719-b39a-c9e5b1329b1c

# %%
evaluator.start_stream()
# Out:
# DEBUG - Restoring setting to iteration 0
# DEBUG - Preparing evaluator for streaming
# DEBUG - First step, getting training data
# DEBUG - (user x item) shape defined is (np.int32(80587), np.int32(59618)). Shape of dataframe stored in matrix was (104702, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(80587), np.int32(59618))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(80587), np.int32(59919)). Shape of dataframe stored in matrix was (103, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(80587), np.int32(59919))
# DEBUG - (user x item) shape defined is (np.int32(80587), np.int32(59919)). Shape of dataframe stored in matrix was (103, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(80587), np.int32(59919))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned NEW -> READY
# DEBUG - Evaluator is ready for streaming
# INFO - Evaluator transitioned to EvaluatorState.STARTED

# %% [markdown]
# # Iteration 1

# %%
data = evaluator.get_training_data(external_model_id)
if data is None:
    raise ValueError("No data available for the external model.")
external_model.fit(data)
# Out:
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 34251 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.22s
# ItemKNNIncremental(K=100, pad_with_popularity=False)

# %%
ul_data = evaluator.get_unlabeled_data(external_model_id)
# Out:
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c

# %%
prediction = external_model.predict(ul_data)
# Out:
# WARNING - ItemKNNIncremental missing similar items for 34251 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(59618, 59920) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(80587, 80588) with random items
# DEBUG - Padding by ItemKNNIncremental completed

# %%
evaluator.submit_prediction(external_model_id, prediction)
# Out:
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (103, 59920) is different from ground truth matrix shape (103, 59919).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (103, 59919)
# DEBUG - Number of ground truth interactions: 103
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1600052710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (103, 59919)
# DEBUG - Number of ground truth interactions: 103
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1600052710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED

# %% [markdown]
# # Iteration 2

# %%
data = evaluator.get_training_data(external_model_id)
# Out:
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(81061), np.int32(59919)). Shape of dataframe stored in matrix was (604, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(81061), np.int32(59919))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(81061), np.int32(60259)). Shape of dataframe stored in matrix was (101, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(81061), np.int32(60259))
# DEBUG - (user x item) shape defined is (np.int32(81061), np.int32(60259)). Shape of dataframe stored in matrix was (101, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(81061), np.int32(60259))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING

# %%
external_model.fit(data)
# Out:
# WARNING - ItemKNNIncremental missing similar items for 34427 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.218s
# ItemKNNIncremental(K=100, pad_with_popularity=False)

# %%
ul_data = evaluator.get_unlabeled_data(external_model_id)
prediction = external_model.predict(ul_data)
evaluator.submit_prediction(external_model_id, prediction)
# Out:
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 34427 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(59919, 60260) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(81061, 81062) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (101, 60260) is different from ground truth matrix shape (101, 60259).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (101, 60259)
# DEBUG - Number of ground truth interactions: 101
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1602644710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (101, 60259)
# DEBUG - Number of ground truth interactions: 101
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1602644710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED

# %% [markdown]
# # Run till completion

# %%
for i in range(setting_window.num_split - 2):
    data = evaluator.get_training_data(external_model_id)
    external_model.fit(data)
    ul_data = evaluator.get_unlabeled_data(external_model_id)
    prediction = external_model.predict(ul_data)
    evaluator.submit_prediction(external_model_id, prediction)
# Out:
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(81595), np.int32(60259)). Shape of dataframe stored in matrix was (660, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(81595), np.int32(60259))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(81595), np.int32(60597)). Shape of dataframe stored in matrix was (109, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(81595), np.int32(60597))
# DEBUG - (user x item) shape defined is (np.int32(81595), np.int32(60597)). Shape of dataframe stored in matrix was (109, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(81595), np.int32(60597))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 34636 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.22s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 34636 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(60259, 60598) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(81595, 81596) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (109, 60598) is different from ground truth matrix shape (109, 60597).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (109, 60597)
# DEBUG - Number of ground truth interactions: 109
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1605236710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (109, 60597)
# DEBUG - Number of ground truth interactions: 109
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1605236710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(82140), np.int32(60597)). Shape of dataframe stored in matrix was (678, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(82140), np.int32(60597))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(82140), np.int32(61011)). Shape of dataframe stored in matrix was (127, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(82140), np.int32(61011))
# DEBUG - (user x item) shape defined is (np.int32(82140), np.int32(61011)). Shape of dataframe stored in matrix was (127, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(82140), np.int32(61011))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 34843 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.224s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 34843 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(60597, 61012) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(82140, 82141) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (127, 61012) is different from ground truth matrix shape (127, 61011).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (127, 61011)
# DEBUG - Number of ground truth interactions: 127
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1607828710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (127, 61011)
# DEBUG - Number of ground truth interactions: 127
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1607828710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(82827), np.int32(61011)). Shape of dataframe stored in matrix was (835, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(82827), np.int32(61011))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(82827), np.int32(61462)). Shape of dataframe stored in matrix was (134, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(82827), np.int32(61462))
# DEBUG - (user x item) shape defined is (np.int32(82827), np.int32(61462)). Shape of dataframe stored in matrix was (134, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(82827), np.int32(61462))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 35111 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.222s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 35111 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(61011, 61463) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(82827, 82828) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (134, 61463) is different from ground truth matrix shape (134, 61462).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (134, 61462)
# DEBUG - Number of ground truth interactions: 134
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1610420710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (134, 61462)
# DEBUG - Number of ground truth interactions: 134
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1610420710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(83568), np.int32(61462)). Shape of dataframe stored in matrix was (907, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(83568), np.int32(61462))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(83568), np.int32(61930)). Shape of dataframe stored in matrix was (138, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(83568), np.int32(61930))
# DEBUG - (user x item) shape defined is (np.int32(83568), np.int32(61930)). Shape of dataframe stored in matrix was (138, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(83568), np.int32(61930))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 35396 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.223s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 35396 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(61462, 61931) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(83568, 83569) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (138, 61931) is different from ground truth matrix shape (138, 61930).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (138, 61930)
# DEBUG - Number of ground truth interactions: 138
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1613012710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (138, 61930)
# DEBUG - Number of ground truth interactions: 138
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1613012710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(84366), np.int32(61930)). Shape of dataframe stored in matrix was (985, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(84366), np.int32(61930))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(84366), np.int32(62410)). Shape of dataframe stored in matrix was (186, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(84366), np.int32(62410))
# DEBUG - (user x item) shape defined is (np.int32(84366), np.int32(62410)). Shape of dataframe stored in matrix was (186, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(84366), np.int32(62410))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 35689 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.223s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 35689 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(61930, 62411) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(84366, 84367) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (186, 62411) is different from ground truth matrix shape (186, 62410).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (186, 62410)
# DEBUG - Number of ground truth interactions: 186
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1615604710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (186, 62410)
# DEBUG - Number of ground truth interactions: 186
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1615604710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(85133), np.int32(62410)). Shape of dataframe stored in matrix was (1008, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(85133), np.int32(62410))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(85133), np.int32(62909)). Shape of dataframe stored in matrix was (157, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(85133), np.int32(62909))
# DEBUG - (user x item) shape defined is (np.int32(85133), np.int32(62909)). Shape of dataframe stored in matrix was (157, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(85133), np.int32(62909))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 35944 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.232s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 35944 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(62410, 62910) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(85133, 85134) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (157, 62910) is different from ground truth matrix shape (157, 62909).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (157, 62909)
# DEBUG - Number of ground truth interactions: 157
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1618196710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (157, 62909)
# DEBUG - Number of ground truth interactions: 157
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1618196710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(85956), np.int32(62909)). Shape of dataframe stored in matrix was (1046, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(85956), np.int32(62909))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(85956), np.int32(63338)). Shape of dataframe stored in matrix was (177, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(85956), np.int32(63338))
# DEBUG - (user x item) shape defined is (np.int32(85956), np.int32(63338)). Shape of dataframe stored in matrix was (177, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(85956), np.int32(63338))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 36234 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.229s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 36234 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(62909, 63339) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(85956, 85957) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (177, 63339) is different from ground truth matrix shape (177, 63338).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (177, 63338)
# DEBUG - Number of ground truth interactions: 177
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1620788710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (177, 63338)
# DEBUG - Number of ground truth interactions: 177
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1620788710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(86639), np.int32(63338)). Shape of dataframe stored in matrix was (896, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(86639), np.int32(63338))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(86639), np.int32(63790)). Shape of dataframe stored in matrix was (193, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(86639), np.int32(63790))
# DEBUG - (user x item) shape defined is (np.int32(86639), np.int32(63790)). Shape of dataframe stored in matrix was (193, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(86639), np.int32(63790))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 36465 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.231s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 36465 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(63338, 63791) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(86639, 86640) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (193, 63791) is different from ground truth matrix shape (193, 63790).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (193, 63790)
# DEBUG - Number of ground truth interactions: 193
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1623380710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (193, 63790)
# DEBUG - Number of ground truth interactions: 193
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1623380710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(87393), np.int32(63790)). Shape of dataframe stored in matrix was (986, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(87393), np.int32(63790))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(87393), np.int32(64226)). Shape of dataframe stored in matrix was (153, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(87393), np.int32(64226))
# DEBUG - (user x item) shape defined is (np.int32(87393), np.int32(64226)). Shape of dataframe stored in matrix was (153, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(87393), np.int32(64226))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 36681 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.234s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 36681 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(63790, 64227) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(87393, 87394) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (153, 64227) is different from ground truth matrix shape (153, 64226).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (153, 64226)
# DEBUG - Number of ground truth interactions: 153
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1625972710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (153, 64226)
# DEBUG - Number of ground truth interactions: 153
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1625972710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(88137), np.int32(64226)). Shape of dataframe stored in matrix was (931, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(88137), np.int32(64226))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(88137), np.int32(64597)). Shape of dataframe stored in matrix was (154, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(88137), np.int32(64597))
# DEBUG - (user x item) shape defined is (np.int32(88137), np.int32(64597)). Shape of dataframe stored in matrix was (154, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(88137), np.int32(64597))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 36937 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.24s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 36937 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(64226, 64598) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(88137, 88138) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (154, 64598) is different from ground truth matrix shape (154, 64597).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (154, 64597)
# DEBUG - Number of ground truth interactions: 154
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1628564710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (154, 64597)
# DEBUG - Number of ground truth interactions: 154
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1628564710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(88756), np.int32(64597)). Shape of dataframe stored in matrix was (801, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(88756), np.int32(64597))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(88756), np.int32(64915)). Shape of dataframe stored in matrix was (125, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(88756), np.int32(64915))
# DEBUG - (user x item) shape defined is (np.int32(88756), np.int32(64915)). Shape of dataframe stored in matrix was (125, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(88756), np.int32(64915))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37144 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.238s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 37144 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(64597, 64916) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(88756, 88757) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (125, 64916) is different from ground truth matrix shape (125, 64915).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (125, 64915)
# DEBUG - Number of ground truth interactions: 125
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1631156710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (125, 64915)
# DEBUG - Number of ground truth interactions: 125
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1631156710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(89339), np.int32(64915)). Shape of dataframe stored in matrix was (727, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(89339), np.int32(64915))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(89339), np.int32(65250)). Shape of dataframe stored in matrix was (121, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(89339), np.int32(65250))
# DEBUG - (user x item) shape defined is (np.int32(89339), np.int32(65250)). Shape of dataframe stored in matrix was (121, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(89339), np.int32(65250))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37321 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.236s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 37321 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(64915, 65251) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(89339, 89340) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (121, 65251) is different from ground truth matrix shape (121, 65250).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (121, 65250)
# DEBUG - Number of ground truth interactions: 121
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1633748710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (121, 65250)
# DEBUG - Number of ground truth interactions: 121
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1633748710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(89903), np.int32(65250)). Shape of dataframe stored in matrix was (710, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(89903), np.int32(65250))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(89903), np.int32(65570)). Shape of dataframe stored in matrix was (111, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(89903), np.int32(65570))
# DEBUG - (user x item) shape defined is (np.int32(89903), np.int32(65570)). Shape of dataframe stored in matrix was (111, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(89903), np.int32(65570))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37516 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.234s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 37516 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(65250, 65571) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(89903, 89904) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (111, 65571) is different from ground truth matrix shape (111, 65570).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (111, 65570)
# DEBUG - Number of ground truth interactions: 111
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1636340710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (111, 65570)
# DEBUG - Number of ground truth interactions: 111
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1636340710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(90419), np.int32(65570)). Shape of dataframe stored in matrix was (641, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(90419), np.int32(65570))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(90419), np.int32(65942)). Shape of dataframe stored in matrix was (131, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(90419), np.int32(65942))
# DEBUG - (user x item) shape defined is (np.int32(90419), np.int32(65942)). Shape of dataframe stored in matrix was (131, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(90419), np.int32(65942))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37705 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.247s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 37705 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(65570, 65943) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(90419, 90420) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (131, 65943) is different from ground truth matrix shape (131, 65942).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (131, 65942)
# DEBUG - Number of ground truth interactions: 131
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1638932710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (131, 65942)
# DEBUG - Number of ground truth interactions: 131
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1638932710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(91169), np.int32(65942)). Shape of dataframe stored in matrix was (900, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(91169), np.int32(65942))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(91169), np.int32(66308)). Shape of dataframe stored in matrix was (136, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(91169), np.int32(66308))
# DEBUG - (user x item) shape defined is (np.int32(91169), np.int32(66308)). Shape of dataframe stored in matrix was (136, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(91169), np.int32(66308))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37930 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.24s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 37930 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(65942, 66309) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(91169, 91170) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (136, 66309) is different from ground truth matrix shape (136, 66308).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (136, 66308)
# DEBUG - Number of ground truth interactions: 136
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1641524710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (136, 66308)
# DEBUG - Number of ground truth interactions: 136
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1641524710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(91916), np.int32(66308)). Shape of dataframe stored in matrix was (919, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(91916), np.int32(66308))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(91916), np.int32(66596)). Shape of dataframe stored in matrix was (139, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(91916), np.int32(66596))
# DEBUG - (user x item) shape defined is (np.int32(91916), np.int32(66596)). Shape of dataframe stored in matrix was (139, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(91916), np.int32(66596))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 38118 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.24s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 38118 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(66308, 66597) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(91916, 91917) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (139, 66597) is different from ground truth matrix shape (139, 66596).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (139, 66596)
# DEBUG - Number of ground truth interactions: 139
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1644116710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (139, 66596)
# DEBUG - Number of ground truth interactions: 139
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1644116710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(92479), np.int32(66596)). Shape of dataframe stored in matrix was (729, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(92479), np.int32(66596))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(92479), np.int32(66912)). Shape of dataframe stored in matrix was (118, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(92479), np.int32(66912))
# DEBUG - (user x item) shape defined is (np.int32(92479), np.int32(66912)). Shape of dataframe stored in matrix was (118, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(92479), np.int32(66912))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 38247 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.239s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 38247 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(66596, 66913) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(92479, 92480) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (118, 66913) is different from ground truth matrix shape (118, 66912).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (118, 66912)
# DEBUG - Number of ground truth interactions: 118
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1646708710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (118, 66912)
# DEBUG - Number of ground truth interactions: 118
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1646708710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(93083), np.int32(66912)). Shape of dataframe stored in matrix was (760, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(93083), np.int32(66912))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(93083), np.int32(67170)). Shape of dataframe stored in matrix was (120, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(93083), np.int32(67170))
# DEBUG - (user x item) shape defined is (np.int32(93083), np.int32(67170)). Shape of dataframe stored in matrix was (120, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(93083), np.int32(67170))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 38399 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.24s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 38399 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(66912, 67171) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(93083, 93084) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (120, 67171) is different from ground truth matrix shape (120, 67170).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (120, 67170)
# DEBUG - Number of ground truth interactions: 120
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1649300710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (120, 67170)
# DEBUG - Number of ground truth interactions: 120
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1649300710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(93574), np.int32(67170)). Shape of dataframe stored in matrix was (631, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(93574), np.int32(67170))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(93574), np.int32(67445)). Shape of dataframe stored in matrix was (127, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(93574), np.int32(67445))
# DEBUG - (user x item) shape defined is (np.int32(93574), np.int32(67445)). Shape of dataframe stored in matrix was (127, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(93574), np.int32(67445))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 38540 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.244s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 38540 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(67170, 67446) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(93574, 93575) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (127, 67446) is different from ground truth matrix shape (127, 67445).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (127, 67445)
# DEBUG - Number of ground truth interactions: 127
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1651892710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (127, 67445)
# DEBUG - Number of ground truth interactions: 127
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1651892710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# ...
# WARNING - Prediction matrix shape (146, 70110) is different from ground truth matrix shape (146, 70109).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (146, 70109)
# DEBUG - Number of ground truth interactions: 146
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1677812710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (146, 70109)
# DEBUG - Number of ground truth interactions: 146
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1677812710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(99996), np.int32(70109)). Shape of dataframe stored in matrix was (788, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(99996), np.int32(70109))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(99996), np.int32(70270)). Shape of dataframe stored in matrix was (67, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(99996), np.int32(70270))
# DEBUG - (user x item) shape defined is (np.int32(99996), np.int32(70270)). Shape of dataframe stored in matrix was (67, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(99996), np.int32(70270))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 39830 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.26s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 39830 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(70109, 70271) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(99996, 99997) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (67, 70271) is different from ground truth matrix shape (67, 70270).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (67, 70270)
# DEBUG - Number of ground truth interactions: 67
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1680404710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (67, 70270)
# DEBUG - Number of ground truth interactions: 67
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1680404710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(100357), np.int32(70270)). Shape of dataframe stored in matrix was (444, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100357), np.int32(70270))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(100357), np.int32(70361)). Shape of dataframe stored in matrix was (31, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100357), np.int32(70361))
# DEBUG - (user x item) shape defined is (np.int32(100357), np.int32(70361)). Shape of dataframe stored in matrix was (31, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100357), np.int32(70361))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 39922 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.264s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 39922 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(70270, 70362) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(100357, 100358) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (31, 70362) is different from ground truth matrix shape (31, 70361).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (31, 70361)
# DEBUG - Number of ground truth interactions: 31
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1682996710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (31, 70361)
# DEBUG - Number of ground truth interactions: 31
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1682996710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(100578), np.int32(70361)). Shape of dataframe stored in matrix was (264, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100578), np.int32(70361))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(100578), np.int32(70422)). Shape of dataframe stored in matrix was (5, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100578), np.int32(70422))
# DEBUG - (user x item) shape defined is (np.int32(100578), np.int32(70422)). Shape of dataframe stored in matrix was (5, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100578), np.int32(70422))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 39978 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.266s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 39978 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(70361, 70423) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(100578, 100579) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (5, 70423) is different from ground truth matrix shape (5, 70422).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (5, 70422)
# DEBUG - Number of ground truth interactions: 5
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1685588710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (5, 70422)
# DEBUG - Number of ground truth interactions: 5
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1685588710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(100741), np.int32(70422)). Shape of dataframe stored in matrix was (183, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100741), np.int32(70422))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(100741), np.int32(70472)). Shape of dataframe stored in matrix was (8, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100741), np.int32(70472))
# DEBUG - (user x item) shape defined is (np.int32(100741), np.int32(70472)). Shape of dataframe stored in matrix was (8, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100741), np.int32(70472))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 40026 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.257s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 40026 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(70422, 70473) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(100741, 100742) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (8, 70473) is different from ground truth matrix shape (8, 70472).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8, 70472)
# DEBUG - Number of ground truth interactions: 8
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1688180710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8, 70472)
# DEBUG - Number of ground truth interactions: 8
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1688180710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(100853), np.int32(70472)). Shape of dataframe stored in matrix was (128, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100853), np.int32(70472))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(100853), np.int32(70508)). Shape of dataframe stored in matrix was (7, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100853), np.int32(70508))
# DEBUG - (user x item) shape defined is (np.int32(100853), np.int32(70508)). Shape of dataframe stored in matrix was (7, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100853), np.int32(70508))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 40058 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.265s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 40058 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(70472, 70509) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(100853, 100854) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (7, 70509) is different from ground truth matrix shape (7, 70508).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (7, 70508)
# DEBUG - Number of ground truth interactions: 7
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1690772710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (7, 70508)
# DEBUG - Number of ground truth interactions: 7
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1690772710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int32(100942), np.int32(70508)). Shape of dataframe stored in matrix was (108, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100942), np.int32(70508))
# DEBUG - Performing users_in comparison
# DEBUG - (user x item) shape defined is (np.int32(100942), np.int32(70511)). Shape of dataframe stored in matrix was (1, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100942), np.int32(70511))
# DEBUG - (user x item) shape defined is (np.int32(100942), np.int32(70511)). Shape of dataframe stored in matrix was (1, 6) before masking
# DEBUG - Final (user x item) shape defined is (np.int32(100942), np.int32(70511))
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 40077 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.265s
# DEBUG - Getting unlabeled data for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - ItemKNNIncremental missing similar items for 40077 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(70508, 70512) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(100942, 100943) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c
# WARNING - Prediction matrix shape (1, 70512) is different from ground truth matrix shape (1, 70511).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (1, 70511)
# DEBUG - Number of ground truth interactions: 1
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1693364710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (1, 70511)
# DEBUG - Number of ground truth interactions: 1
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1693364710) created for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c
# DEBUG - Prediction evaluated for algorithm cb605b33-7733-5719-b39a-c9e5b1329b1c complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED

# %% [markdown]
# # evaluate metrics

# %%
evaluator.get_all_algorithm_status()
# Out:
# {'ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c': <AlgorithmStateEnum.PREDICTED: 'PREDICTED'>}

# %%
evaluator.metric_results("macro")
# Out:
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1610420710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1610420710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1623380710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1623380710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1677812710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1677812710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1688180710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1688180710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1690772710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1690772710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1693364710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1693364710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
#                                                                    macro_score  \
# algorithm                                          metric
# ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5... PrecisionK_100     0.000221
#                                                    RecallK_100        0.022094
#
#                                                                    num_window
# algorithm                                          metric
# ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5... PrecisionK_100          37
#                                                    RecallK_100             37

# %%
evaluator.metric_results("micro")
# Out:
#                                                                   micro_score  \
# algorithm                                          metric
# ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5... PrecisionK_100    0.000148
#                                                    RecallK_100       0.014789
#
#                                                                    num_user
# algorithm                                          metric
# ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5... PrecisionK_100      3688
#                                                    RecallK_100         3688

# %%
evaluator.metric_results("user")
# Out:
#                                                                                user_id  \
# algorithm                                          timestamp    metric
# ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5... t=1600052710 PrecisionK_100      76
#                                                                 PrecisionK_100    2104
#                                                                 PrecisionK_100    2395
#                                                                 PrecisionK_100    3359
#                                                                 PrecisionK_100    6472
# ...                                                                                ...
#                                                    t=1690772710 RecallK_100     100380
#                                                                 RecallK_100     100755
#                                                                 RecallK_100     100828
#                                                    t=1693364710 PrecisionK_100  100857
#                                                                 RecallK_100     100857
#
#                                                                                user_score
# algorithm                                          timestamp    metric
# ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5... t=1600052710 PrecisionK_100        0.0
#                                                                 PrecisionK_100        0.0
#                                                                 PrecisionK_100        0.0
#                                                                 PrecisionK_100        0.0
#                                                                 PrecisionK_100        0.0
# ...                                                                                   ...
#                                                    t=1690772710 RecallK_100           0.0
#                                                                 RecallK_100           0.0
#                                                                 RecallK_100           0.0
#                                                    t=1693364710 PrecisionK_100        0.0
#                                                                 RecallK_100           0.0
#
# [7376 rows x 2 columns]

# %%
evaluator.metric_results("window")
# Out:
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1610420710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1610420710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1623380710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1623380710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1677812710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1677812710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1688180710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1688180710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1690772710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1690772710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1693364710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1693364710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5b1329b1c did not have any correct predictions.
#                                                                                 window_score  \
# algorithm                                          timestamp    metric
# ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5... t=1600052710 PrecisionK_100      0.000097
#                                                                 RecallK_100         0.009709
#                                                    t=1602644710 PrecisionK_100      0.000495
#                                                                 RecallK_100         0.049505
#                                                    t=1605236710 PrecisionK_100      0.000275
# ...                                                                                      ...
#                                                    t=1688180710 RecallK_100         0.000000
#                                                    t=1690772710 PrecisionK_100      0.000000
#                                                                 RecallK_100         0.000000
#                                                    t=1693364710 PrecisionK_100      0.000000
#                                                                 RecallK_100         0.000000
#
#                                                                                 num_user
# algorithm                                          timestamp    metric
# ItemKNNIncremental_cb605b33-7733-5719-b39a-c9e5... t=1600052710 PrecisionK_100       103
#                                                                 RecallK_100          103
#                                                    t=1602644710 PrecisionK_100       101
#                                                                 RecallK_100          101
#                                                    t=1605236710 PrecisionK_100       109
# ...                                                                                  ...
#                                                    t=1688180710 RecallK_100            8
#                                                    t=1690772710 PrecisionK_100         7
#                                                                 RecallK_100            7
#                                                    t=1693364710 PrecisionK_100         1
#                                                                 RecallK_100            1
#
# [74 rows x 2 columns]
