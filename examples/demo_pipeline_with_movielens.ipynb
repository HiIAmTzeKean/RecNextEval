# %% [markdown]
# # Recorded Demo of RecNextEval for SIGIR 2026 Presentation
#
# Paper title: RecNextEval: A Reference Implementation for Temporal Next-Batch Recommendation Evaluation
#
# Presenter: Ng Tze Kean
#
# Presentation paramters:
#
# - Dataset: MovieLens100K
# - Top K = 10
# - Algorithm: ItemKNNIncremental, RecentPopularity
# - First timestamp split at epoch time 875_156_710

# %%
from recnexteval.datasets import MovieLens100K
from recnexteval.settings import SlidingWindowSetting


k = 10
dataset = MovieLens100K()
data = dataset.load()

setting_window = SlidingWindowSetting(
    training_t=875_156_710,
    window_size=60 * 60 * 24 * 30,  # day times N
    top_K=k
)

setting_window.split(data)
# Out:
# INFO - recnexteval package loaded.
# DEBUG - MovieLens100K being initialized with '/Users/ngtzekean/personal/RecNextEval/data/movielens' as the base path.
# DEBUG - MovieLens100K is initialized.
# INFO - MovieLens100K is loading dataset...
# INFO - Loading from cache: /Users/ngtzekean/personal/RecNextEval/data/movielens/ml-100k_u.data.processed.parquet
# DEBUG - MovieLens100K applying filters set.
# DEBUG - 	interactions before preprocess: 100000
# DEBUG - 	items before preprocess: 1682
# DEBUG - 	users before preprocess: 943
# DEBUG - 	interactions after preprocess: 100000
# DEBUG - 	items after preprocess: 1682
# DEBUG - 	users after preprocess: 943
# INFO - MovieLens100K dataset loaded - Took 0.0451s
# DEBUG - Splitting data...
# DEBUG - Performing lt(t, 2147483647)
# DEBUG - Performing lt(t, 875156710)
# DEBUG - Performing ge(t, 875156710)
# DEBUG - Performing lt(t, 3022640357)
# DEBUG - TimestampSplitter(t=875156710,t_lower=None,t_upper=2147483647) has complete split
#   0%|          | 0/6 [00:00<?, ?it/s]
# DEBUG - NLastInteractionTimestampSplitter(t=875156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=875156710
# DEBUG - Performing lt(t, 877748710)
# DEBUG - Performing ge(t, 875156710)
# DEBUG - NLastInteractionTimestampSplitter(t=875156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 875156710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=875156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=877748710
# DEBUG - Performing lt(t, 880340710)
# DEBUG - Performing ge(t, 877748710)
# DEBUG - NLastInteractionTimestampSplitter(t=877748710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 877748710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=877748710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=880340710
# DEBUG - Performing lt(t, 882932710)
# DEBUG - Performing ge(t, 880340710)
# DEBUG - NLastInteractionTimestampSplitter(t=880340710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 880340710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=880340710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=882932710
# DEBUG - Performing lt(t, 885524710)
# DEBUG - Performing ge(t, 882932710)
# DEBUG - NLastInteractionTimestampSplitter(t=882932710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 882932710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=882932710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=885524710
# DEBUG - Performing lt(t, 888116710)
# DEBUG - Performing ge(t, 885524710)
# DEBUG - NLastInteractionTimestampSplitter(t=885524710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 885524710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=885524710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=888116710
# DEBUG - Performing lt(t, 890708710)
# DEBUG - Performing ge(t, 888116710)
# DEBUG - NLastInteractionTimestampSplitter(t=888116710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 888116710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=888116710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=890708710
# DEBUG - Performing lt(t, 893300710)
# DEBUG - Performing ge(t, 890708710)
# DEBUG - NLastInteractionTimestampSplitter(t=890708710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 890708710 resulted in empty unlabelled testing samples.
# 7it [00:00, 197.56it/s]
# INFO - Finished split with window size 2592000 seconds. Number of splits: 7 in total.
# INFO - SlidingWindowSetting data split - Took 0.0488s
# DEBUG - Checking split attribute and sizes.
# DEBUG - Checking split attributes.
# DEBUG - Split attributes are set.
# DEBUG - Checking size of split sets.
# WARNING - /Users/ngtzekean/personal/RecNextEval/src/recnexteval/settings/base.py:274: UserWarning: Background data resulting from SlidingWindowSetting is unusually small.
#   warn(UserWarning(f"{name} resulting from {self.name} is unusually small."))
#
# DEBUG - Size of split sets are checked.
# INFO - SlidingWindowSetting data split complete.

# %%
from recnexteval.algorithms import DecayPopularity, ItemKNNIncremental, RecentPopularity
from recnexteval.evaluators import EvaluatorPipelineBuilder


builder = EvaluatorPipelineBuilder()
builder.add_setting(setting_window)
builder.set_metric_k(k)
# builder.add_metric("RecallK")
builder.add_metric("NDCGK")
builder.add_metric("HitK")
# builder.add_algorithm(ItemKNNIncremental, params={"K": k})
builder.add_algorithm(ItemKNNIncremental, params={"K": k})
builder.add_algorithm(RecentPopularity, params={"K": k})
builder.add_algorithm(DecayPopularity, params={"K": k})
evaluator = builder.build()
# Out:
# INFO - Registered algorithm 'ItemKNNIncremental(K=10,pad_with_popularity=False)' with ID 51476e85-ee3a-5260-918a-1ad1856df1d7
# INFO - Registered algorithm 'RecentPopularity(K=10)' with ID 8c4cf57c-4e77-567a-95fe-41ade21a0148
# INFO - Registered algorithm 'DecayPopularity(K=10)' with ID b48e753c-438c-5e9c-8e4a-df9b2faddf38

# %%
evaluator.run()
# Out:
# DEBUG - First step, getting training data
# DEBUG - (user x item) shape defined is (np.int16(41), np.int16(872)). Shape of dataframe stored in matrix was (3446, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(41), np.int16(872))
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0111s
# DEBUG - Fitting RecentPopularity complete - Took 0.00142s
# DEBUG - Fitting DecayPopularity complete - Took 0.000816s
# DEBUG - Algorithms trained with background data...
# DEBUG - Metric accumulator instantiated...
# DEBUG - Restoring setting to iteration 0
# DEBUG - Setting data generators ready...
# Evaluating steps:   0%|          | 0/7 [00:00<?, ?it/s]
# INFO - Running step 0
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (np.int16(174), np.int16(1177)). Shape of dataframe stored in matrix was (1463, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(174), np.int16(1177))
# DEBUG - (user x item) shape defined is (np.int16(174), np.int16(1177)). Shape of dataframe stored in matrix was (1463, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(174), np.int16(1177))
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(872, 1178) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(41, 175) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (1463, 1178)
# DEBUG - Shape of ground truth matrix: (1463, 1177)
# WARNING - Prediction matrix shape (1463, 1178) is different from ground truth matrix shape (1463, 1177).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1463
# DEBUG - Number of ground truth interactions: 1463
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=875156710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1463
# DEBUG - Number of ground truth interactions: 1463
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=875156710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1463, 872)
# DEBUG - Shape of ground truth matrix: (1463, 1177)
# WARNING - Prediction matrix shape (1463, 872) is different from ground truth matrix shape (1463, 1177).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1463
# DEBUG - Number of ground truth interactions: 1463
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=875156710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1463
# DEBUG - Number of ground truth interactions: 1463
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=875156710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1463, 872)
# DEBUG - Shape of ground truth matrix: (1463, 1177)
# WARNING - Prediction matrix shape (1463, 872) is different from ground truth matrix shape (1463, 1177).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1463
# DEBUG - Number of ground truth interactions: 1463
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=875156710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1463
# DEBUG - Number of ground truth interactions: 1463
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=875156710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int16(174), np.int16(1192)). Shape of dataframe stored in matrix was (11661, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(174), np.int16(1192))
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0193s
# DEBUG - Fitting RecentPopularity complete - Took 0.000937s
# DEBUG - Fitting DecayPopularity complete - Took 0.000912s
# INFO - Running step 1
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (np.int16(391), np.int16(1388)). Shape of dataframe stored in matrix was (2534, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(391), np.int16(1388))
# DEBUG - (user x item) shape defined is (np.int16(391), np.int16(1388)). Shape of dataframe stored in matrix was (2534, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(391), np.int16(1388))
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(1192, 1389) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(174, 392) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (2534, 1389)
# DEBUG - Shape of ground truth matrix: (2534, 1388)
# WARNING - Prediction matrix shape (2534, 1389) is different from ground truth matrix shape (2534, 1388).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 2534
# DEBUG - Number of ground truth interactions: 2534
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=877748710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 2534
# DEBUG - Number of ground truth interactions: 2534
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=877748710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (2534, 1192)
# DEBUG - Shape of ground truth matrix: (2534, 1388)
# WARNING - Prediction matrix shape (2534, 1192) is different from ground truth matrix shape (2534, 1388).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 2534
# DEBUG - Number of ground truth interactions: 2534
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=877748710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 2534
# DEBUG - Number of ground truth interactions: 2534
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=877748710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (2534, 1192)
# DEBUG - Shape of ground truth matrix: (2534, 1388)
# WARNING - Prediction matrix shape (2534, 1192) is different from ground truth matrix shape (2534, 1388).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 2534
# DEBUG - Number of ground truth interactions: 2534
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=877748710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 2534
# DEBUG - Number of ground truth interactions: 2534
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=877748710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# Evaluating steps:  29%|██▊       | 2/7 [00:00<00:00, 17.60it/s]
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int16(391), np.int16(1411)). Shape of dataframe stored in matrix was (21810, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(391), np.int16(1411))
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0308s
# DEBUG - Fitting RecentPopularity complete - Took 0.00126s
# DEBUG - Fitting DecayPopularity complete - Took 0.00135s
# INFO - Running step 2
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (np.int16(497), np.int16(1467)). Shape of dataframe stored in matrix was (1607, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(497), np.int16(1467))
# DEBUG - (user x item) shape defined is (np.int16(497), np.int16(1467)). Shape of dataframe stored in matrix was (1607, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(497), np.int16(1467))
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(1411, 1468) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(391, 498) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (1607, 1468)
# DEBUG - Shape of ground truth matrix: (1607, 1467)
# WARNING - Prediction matrix shape (1607, 1468) is different from ground truth matrix shape (1607, 1467).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1607
# DEBUG - Number of ground truth interactions: 1607
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=880340710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1607
# DEBUG - Number of ground truth interactions: 1607
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=880340710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1607, 1411)
# DEBUG - Shape of ground truth matrix: (1607, 1467)
# WARNING - Prediction matrix shape (1607, 1411) is different from ground truth matrix shape (1607, 1467).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1607
# DEBUG - Number of ground truth interactions: 1607
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=880340710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1607
# DEBUG - Number of ground truth interactions: 1607
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=880340710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1607, 1411)
# DEBUG - Shape of ground truth matrix: (1607, 1467)
# WARNING - Prediction matrix shape (1607, 1411) is different from ground truth matrix shape (1607, 1467).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1607
# DEBUG - Number of ground truth interactions: 1607
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=880340710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1607
# DEBUG - Number of ground truth interactions: 1607
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=880340710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int16(497), np.int16(1467)). Shape of dataframe stored in matrix was (13649, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(497), np.int16(1467))
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0377s
# DEBUG - Fitting RecentPopularity complete - Took 0.000887s
# DEBUG - Fitting DecayPopularity complete - Took 0.00106s
# INFO - Running step 3
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (np.int16(618), np.int16(1515)). Shape of dataframe stored in matrix was (1889, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(618), np.int16(1515))
# DEBUG - (user x item) shape defined is (np.int16(618), np.int16(1515)). Shape of dataframe stored in matrix was (1889, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(618), np.int16(1515))
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(1467, 1516) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(497, 619) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (1889, 1516)
# DEBUG - Shape of ground truth matrix: (1889, 1515)
# WARNING - Prediction matrix shape (1889, 1516) is different from ground truth matrix shape (1889, 1515).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1889
# DEBUG - Number of ground truth interactions: 1889
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=882932710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1889
# DEBUG - Number of ground truth interactions: 1889
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=882932710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1889, 1467)
# DEBUG - Shape of ground truth matrix: (1889, 1515)
# WARNING - Prediction matrix shape (1889, 1467) is different from ground truth matrix shape (1889, 1515).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1889
# DEBUG - Number of ground truth interactions: 1889
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=882932710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1889
# DEBUG - Number of ground truth interactions: 1889
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=882932710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1889, 1467)
# DEBUG - Shape of ground truth matrix: (1889, 1515)
# WARNING - Prediction matrix shape (1889, 1467) is different from ground truth matrix shape (1889, 1515).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1889
# DEBUG - Number of ground truth interactions: 1889
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=882932710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1889
# DEBUG - Number of ground truth interactions: 1889
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=882932710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# Evaluating steps:  57%|█████▋    | 4/7 [00:00<00:00, 13.55it/s]
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int16(618), np.int16(1515)). Shape of dataframe stored in matrix was (12069, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(618), np.int16(1515))
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0418s
# DEBUG - Fitting RecentPopularity complete - Took 0.00112s
# DEBUG - Fitting DecayPopularity complete - Took 0.00116s
# INFO - Running step 4
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (np.int16(703), np.int16(1594)). Shape of dataframe stored in matrix was (1453, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(703), np.int16(1594))
# DEBUG - (user x item) shape defined is (np.int16(703), np.int16(1594)). Shape of dataframe stored in matrix was (1453, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(703), np.int16(1594))
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(1515, 1595) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(618, 704) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (1453, 1595)
# DEBUG - Shape of ground truth matrix: (1453, 1594)
# WARNING - Prediction matrix shape (1453, 1595) is different from ground truth matrix shape (1453, 1594).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1453
# DEBUG - Number of ground truth interactions: 1453
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=885524710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1453
# DEBUG - Number of ground truth interactions: 1453
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=885524710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1453, 1515)
# DEBUG - Shape of ground truth matrix: (1453, 1594)
# WARNING - Prediction matrix shape (1453, 1515) is different from ground truth matrix shape (1453, 1594).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1453
# DEBUG - Number of ground truth interactions: 1453
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=885524710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1453
# DEBUG - Number of ground truth interactions: 1453
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=885524710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1453, 1515)
# DEBUG - Shape of ground truth matrix: (1453, 1594)
# WARNING - Prediction matrix shape (1453, 1515) is different from ground truth matrix shape (1453, 1594).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1453
# DEBUG - Number of ground truth interactions: 1453
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=885524710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1453
# DEBUG - Number of ground truth interactions: 1453
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=885524710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int16(703), np.int16(1594)). Shape of dataframe stored in matrix was (11669, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(703), np.int16(1594))
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0502s
# DEBUG - Fitting RecentPopularity complete - Took 0.000913s
# DEBUG - Fitting DecayPopularity complete - Took 0.00111s
# INFO - Running step 5
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (np.int16(782), np.int16(1621)). Shape of dataframe stored in matrix was (1496, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(782), np.int16(1621))
# DEBUG - (user x item) shape defined is (np.int16(782), np.int16(1621)). Shape of dataframe stored in matrix was (1496, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(782), np.int16(1621))
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(1594, 1622) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(703, 783) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (1496, 1622)
# DEBUG - Shape of ground truth matrix: (1496, 1621)
# WARNING - Prediction matrix shape (1496, 1622) is different from ground truth matrix shape (1496, 1621).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1496
# DEBUG - Number of ground truth interactions: 1496
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=888116710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1496
# DEBUG - Number of ground truth interactions: 1496
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=888116710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1496, 1594)
# DEBUG - Shape of ground truth matrix: (1496, 1621)
# WARNING - Prediction matrix shape (1496, 1594) is different from ground truth matrix shape (1496, 1621).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1496
# DEBUG - Number of ground truth interactions: 1496
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=888116710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1496
# DEBUG - Number of ground truth interactions: 1496
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=888116710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (1496, 1594)
# DEBUG - Shape of ground truth matrix: (1496, 1621)
# WARNING - Prediction matrix shape (1496, 1594) is different from ground truth matrix shape (1496, 1621).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 1496
# DEBUG - Number of ground truth interactions: 1496
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=888116710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 1496
# DEBUG - Number of ground truth interactions: 1496
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=888116710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# Evaluating steps:  86%|████████▌ | 6/7 [00:00<00:00, 11.86it/s]
# DEBUG - Not first step, getting previous ground truth data as training data
# DEBUG - (user x item) shape defined is (np.int16(782), np.int16(1626)). Shape of dataframe stored in matrix was (8919, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(782), np.int16(1626))
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.053s
# DEBUG - Fitting RecentPopularity complete - Took 0.000893s
# DEBUG - Fitting DecayPopularity complete - Took 0.000983s
# INFO - Running step 6
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (np.int16(943), np.int16(1670)). Shape of dataframe stored in matrix was (2120, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(943), np.int16(1670))
# DEBUG - (user x item) shape defined is (np.int16(943), np.int16(1670)). Shape of dataframe stored in matrix was (2120, 5) before masking
# DEBUG - Final (user x item) shape defined is (np.int16(943), np.int16(1670))
# DEBUG - Performing items_in comparison
# DEBUG - Padding item ID in range(1626, 1671) with empty fields
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Padding user ID in range(782, 944) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (2120, 1671)
# DEBUG - Shape of ground truth matrix: (2120, 1670)
# WARNING - Prediction matrix shape (2120, 1671) is different from ground truth matrix shape (2120, 1670).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 2120
# DEBUG - Number of ground truth interactions: 2120
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=890708710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 2120
# DEBUG - Number of ground truth interactions: 2120
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=890708710) created for algorithm ItemKNNIncremental(K=10,pad_with_popularity=False)_51476e85-ee3a-5260-918a-1ad1856df1d7
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (2120, 1626)
# DEBUG - Shape of ground truth matrix: (2120, 1670)
# WARNING - Prediction matrix shape (2120, 1626) is different from ground truth matrix shape (2120, 1670).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 2120
# DEBUG - Number of ground truth interactions: 2120
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=890708710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 2120
# DEBUG - Number of ground truth interactions: 2120
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=890708710) created for algorithm RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-41ade21a0148
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (2120, 1626)
# DEBUG - Shape of ground truth matrix: (2120, 1670)
# WARNING - Prediction matrix shape (2120, 1626) is different from ground truth matrix shape (2120, 1670).
# DEBUG - NDCGK compute started - NDCGK_10
# DEBUG - Number of users: 2120
# DEBUG - Number of ground truth interactions: 2120
# DEBUG - NDCGK compute complete - NDCGK_10
# DEBUG - Metric NDCGK_10(timestamp_limit=890708710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# DEBUG - HitK compute started - HitK_10
# DEBUG - Number of users: 2120
# DEBUG - Number of ground truth interactions: 2120
# DEBUG - HitK compute complete - HitK_10
# DEBUG - Metric HitK_10(timestamp_limit=890708710) created for algorithm DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-df9b2faddf38
# Evaluating steps: 100%|██████████| 7/7 [00:00<00:00, 11.88it/s]

# %% [markdown]
# # evaluate metrics

# %%
evaluator.metric_results("macro")
# Out:
#                                                              macro_score  \
# algorithm                                          metric
# DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-d... HitK_10      0.527113
#                                                    NDCGK_10     0.125114
# ItemKNNIncremental(K=10,pad_with_popularity=Fal... HitK_10      0.366751
#                                                    NDCGK_10     0.166534
# RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-... HitK_10      0.576868
#                                                    NDCGK_10     0.157799
#
#                                                              num_window
# algorithm                                          metric
# DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-d... HitK_10            7
#                                                    NDCGK_10           7
# ItemKNNIncremental(K=10,pad_with_popularity=Fal... HitK_10            7
#                                                    NDCGK_10           7
# RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-... HitK_10            7
#                                                    NDCGK_10           7

# %%
evaluator.metric_results("micro")
# Out:
#                                                             micro_score  \
# algorithm                                          metric
# DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-d... HitK_10     0.097255
#                                                    NDCGK_10    0.113453
# ItemKNNIncremental(K=10,pad_with_popularity=Fal... HitK_10     0.172926
#                                                    NDCGK_10    0.205655
# RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-... HitK_10     0.127239
#                                                    NDCGK_10    0.150742
#
#                                                              num_user
# algorithm                                          metric
# DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-d... HitK_10       1428
#                                                    NDCGK_10      1428
# ItemKNNIncremental(K=10,pad_with_popularity=Fal... HitK_10       1428
#                                                    NDCGK_10      1428
# RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-... HitK_10       1428
#                                                    NDCGK_10      1428

# %%
evaluator.metric_results("user")
# Out:
#                                                                       user_id  \
# algorithm                                          timestamp metric
# ItemKNNIncremental(K=10,pad_with_popularity=Fal... 875156710 NDCGK_10       0
#                                                              NDCGK_10       1
#                                                              NDCGK_10       2
#                                                              NDCGK_10       3
#                                                              NDCGK_10       4
# ...                                                                       ...
# DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-d... 890708710 HitK_10      938
#                                                              HitK_10      939
#                                                              HitK_10      940
#                                                              HitK_10      941
#                                                              HitK_10      942
#
#                                                                       user_score
# algorithm                                          timestamp metric
# ItemKNNIncremental(K=10,pad_with_popularity=Fal... 875156710 NDCGK_10   0.725495
#                                                              NDCGK_10   0.126419
#                                                              NDCGK_10   0.232245
#                                                              NDCGK_10   0.455156
#                                                              NDCGK_10   0.345176
# ...                                                                          ...
# DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-d... 890708710 HitK_10         0.2
#                                                              HitK_10         0.3
#                                                              HitK_10         0.3
#                                                              HitK_10         0.2
#                                                              HitK_10         0.2
#
# [8568 rows x 2 columns]

# %%
from recnexteval.evaluators import MetricLevelEnum

# %%
# you also can use the Enum instead of string for better code completion support
evaluator.metric_results(MetricLevelEnum.WINDOW)
# Out:
#                                                                        window_score  \
# algorithm                                          timestamp metric
# ItemKNNIncremental(K=10,pad_with_popularity=Fal... 875156710 NDCGK_10      0.054930
#                                                              HitK_10       0.207547
#                                                    877748710 NDCGK_10      0.080724
#                                                              HitK_10       0.220974
#                                                    880340710 NDCGK_10      0.190783
#                                                              HitK_10       0.393443
#                                                    882932710 NDCGK_10      0.203331
#                                                              HitK_10       0.415888
#                                                    885524710 NDCGK_10      0.226851
#                                                              HitK_10       0.468927
#                                                    888116710 NDCGK_10      0.259807
#                                                              HitK_10       0.532609
#                                                    890708710 NDCGK_10      0.149314
#                                                              HitK_10       0.327869
# RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-... 875156710 NDCGK_10      0.107547
#                                                              HitK_10       0.459119
#                                                    877748710 NDCGK_10      0.115145
#                                                              HitK_10       0.573034
#                                                    880340710 NDCGK_10      0.145244
#                                                              HitK_10       0.590164
#                                                    882932710 NDCGK_10      0.112848
#                                                              HitK_10       0.471963
#                                                    885524710 NDCGK_10      0.202847
#                                                              HitK_10       0.632768
#                                                    888116710 NDCGK_10      0.169378
#                                                              HitK_10       0.581522
#                                                    890708710 NDCGK_10      0.251582
#                                                              HitK_10       0.729508
# DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-d... 875156710 NDCGK_10      0.107547
#                                                              HitK_10       0.459119
#                                                    877748710 NDCGK_10      0.116007
#                                                              HitK_10       0.576779
#                                                    880340710 NDCGK_10      0.153737
#                                                              HitK_10       0.568306
#                                                    882932710 NDCGK_10      0.116860
#                                                              HitK_10       0.546729
#                                                    885524710 NDCGK_10      0.142464
#                                                              HitK_10       0.508475
#                                                    888116710 NDCGK_10      0.109791
#                                                              HitK_10       0.440217
#                                                    890708710 NDCGK_10      0.129393
#                                                              HitK_10       0.590164
#
#                                                                        num_user
# algorithm                                          timestamp metric
# ItemKNNIncremental(K=10,pad_with_popularity=Fal... 875156710 NDCGK_10      1463
#                                                              HitK_10       1463
#                                                    877748710 NDCGK_10      2534
#                                                              HitK_10       2534
#                                                    880340710 NDCGK_10      1607
#                                                              HitK_10       1607
#                                                    882932710 NDCGK_10      1889
#                                                              HitK_10       1889
#                                                    885524710 NDCGK_10      1453
#                                                              HitK_10       1453
#                                                    888116710 NDCGK_10      1496
#                                                              HitK_10       1496
#                                                    890708710 NDCGK_10      2120
#                                                              HitK_10       2120
# RecentPopularity(K=10)_8c4cf57c-4e77-567a-95fe-... 875156710 NDCGK_10      1463
#                                                              HitK_10       1463
#                                                    877748710 NDCGK_10      2534
#                                                              HitK_10       2534
#                                                    880340710 NDCGK_10      1607
#                                                              HitK_10       1607
#                                                    882932710 NDCGK_10      1889
#                                                              HitK_10       1889
#                                                    885524710 NDCGK_10      1453
#                                                              HitK_10       1453
#                                                    888116710 NDCGK_10      1496
#                                                              HitK_10       1496
#                                                    890708710 NDCGK_10      2120
#                                                              HitK_10       2120
# DecayPopularity(K=10)_b48e753c-438c-5e9c-8e4a-d... 875156710 NDCGK_10      1463
#                                                              HitK_10       1463
#                                                    877748710 NDCGK_10      2534
#                                                              HitK_10       2534
#                                                    880340710 NDCGK_10      1607
#                                                              HitK_10       1607
#                                                    882932710 NDCGK_10      1889
#                                                              HitK_10       1889
#                                                    885524710 NDCGK_10      1453
#                                                              HitK_10       1453
#                                                    888116710 NDCGK_10      1496
#                                                              HitK_10       1496
#                                                    890708710 NDCGK_10      2120
#                                                              HitK_10       2120
